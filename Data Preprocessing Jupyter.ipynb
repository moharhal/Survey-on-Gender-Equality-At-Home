# %%
import pandas as pd

# %%
data=pd.read_excel('countrydata.xlsx')

# %%
data
# Out:
#      Year              Region    Subregion    Gender  sog_w2_wrrd_food_yes  \
# 0    2020          South Asia  Afghanistan    Female                  25.0
# 1    2020          South Asia  Afghanistan      Male                  23.0
# 2    2020          South Asia  Afghanistan  Combined                  24.0
# 3    2021          South Asia  Afghanistan    Female                  63.0
# 4    2021          South Asia  Afghanistan      Male                  67.0
# ..    ...                 ...          ...       ...                   ...
# 787  2020  Sub-Saharan Africa     Zimbabwe      Male                  65.0
# 788  2020  Sub-Saharan Africa     Zimbabwe  Combined                  64.0
# 789  2021  Sub-Saharan Africa     Zimbabwe    Female                   NaN
# 790  2021  Sub-Saharan Africa     Zimbabwe      Male                   NaN
# 791  2021  Sub-Saharan Africa     Zimbabwe  Combined                   NaN
#
#      sog_w2_wrrd_food_no  sog_w2_unsafe_strag_ag  sog_w2_unsafe_neutral  \
# 0                   75.0                    17.0                   14.0
# 1                   77.0                    16.0                   11.0
# 2                   76.0                    17.0                   13.0
# 3                   37.0                    85.0                    9.0
# 4                   33.0                    79.0                    9.0
# ..                   ...                     ...                    ...
# 787                 35.0                    50.0                   11.0
# 788                 36.0                    48.0                   12.0
# 789                  NaN                     NaN                    NaN
# 790                  NaN                     NaN                    NaN
# 791                  NaN                     NaN                    NaN
#
#      sog_w2_unsafe_strdis_dis  sog_w2_wrk_yes  ...  sog_w2_nb_chldrn_2under6  \
# 0                        69.0            54.0  ...                       NaN
# 1                        73.0            59.0  ...                       NaN
# 2                        71.0            56.0  ...                       NaN
# 3                         6.0            56.0  ...                       8.0
# 4                        12.0            65.0  ...                      20.0
# ..                        ...             ...  ...                       ...
# 787                      39.0            61.0  ...                       NaN
# 788                      39.0            55.0  ...                       NaN
# 789                       NaN             NaN  ...                       NaN
# 790                       NaN             NaN  ...                       NaN
# 791                       NaN             NaN  ...                       NaN
#
#      sog_w2_nb_chldrn_3under6  sog_w2_nb_chldrn_over3  sog_w2_nb_chldrn_none  \
# 0                         NaN                     NaN                    NaN
# 1                         NaN                     NaN                    NaN
# 2                         NaN                     NaN                    NaN
# 3                         6.0                     4.0                   39.0
# 4                         7.0                     8.0                   31.0
# ..                        ...                     ...                    ...
# 787                       NaN                     NaN                    NaN
# 788                       NaN                     NaN                    NaN
# 789                       NaN                     NaN                    NaN
# 790                       NaN                     NaN                    NaN
# 791                       NaN                     NaN                    NaN
#
#      sog_w2_educ_none  sog_w2_educ_prim  sog_w2_educ_second  \
# 0                 NaN               NaN                 NaN
# 1                 NaN               NaN                 NaN
# 2                 NaN               NaN                 NaN
# 3                 4.0               7.0                14.0
# 4                 3.0               7.0                18.0
# ..                ...               ...                 ...
# 787               NaN               NaN                 NaN
# 788               NaN               NaN                 NaN
# 789               NaN               NaN                 NaN
# 790               NaN               NaN                 NaN
# 791               NaN               NaN                 NaN
#
#      sog_w2_educ_oversecond  sog_w2_educ_uniunderg  sog_w2_educ_unigrad
# 0                       NaN                    NaN                  NaN
# 1                       NaN                    NaN                  NaN
# 2                       NaN                    NaN                  NaN
# 3                      19.0                   49.0                  7.0
# 4                      18.0                   46.0                  9.0
# ..                      ...                    ...                  ...
# 787                     NaN                    NaN                  NaN
# 788                     NaN                    NaN                  NaN
# 789                     NaN                    NaN                  NaN
# 790                     NaN                    NaN                  NaN
# 791                     NaN                    NaN                  NaN
#
# [792 rows x 260 columns]

# %%
data.isnull().sum()
# Out:
# Year                        0
# Region                      0
# Subregion                   0
# Gender                      0
# sog_w2_wrrd_food_yes       78
#                          ...
# sog_w2_educ_prim          447
# sog_w2_educ_second        447
# sog_w2_educ_oversecond    447
# sog_w2_educ_uniunderg     447
# sog_w2_educ_unigrad       447
# Length: 260, dtype: int64

# %%
data_Copy=data.copy()

# %%
for i in range(260):
    for j in data.index:
        
        if(pd.isnull(data_Copy.iloc[j,i])):
            data.iloc[j,i]=data_Copy[data_Copy.columns[i]].mean()

# %%
data
# Out:
#      Year              Region    Subregion    Gender  sog_w2_wrrd_food_yes  \
# 0    2020          South Asia  Afghanistan    Female                  25.0
# 1    2020          South Asia  Afghanistan      Male                  23.0
# 2    2020          South Asia  Afghanistan  Combined                  24.0
# 3    2021          South Asia  Afghanistan    Female                  63.0
# 4    2021          South Asia  Afghanistan      Male                  67.0
# ..    ...                 ...          ...       ...                   ...
# 787  2020  Sub-Saharan Africa     Zimbabwe      Male                  65.0
# 788  2020  Sub-Saharan Africa     Zimbabwe  Combined                  64.0
# 789  2021  Sub-Saharan Africa     Zimbabwe    Female                   NaN
# 790  2021  Sub-Saharan Africa     Zimbabwe      Male                   NaN
# 791  2021  Sub-Saharan Africa     Zimbabwe  Combined                   NaN
#
#      sog_w2_wrrd_food_no  sog_w2_unsafe_strag_ag  sog_w2_unsafe_neutral  \
# 0                   75.0                    17.0                   14.0
# 1                   77.0                    16.0                   11.0
# 2                   76.0                    17.0                   13.0
# 3                   37.0                    85.0                    9.0
# 4                   33.0                    79.0                    9.0
# ..                   ...                     ...                    ...
# 787                 35.0                    50.0                   11.0
# 788                 36.0                    48.0                   12.0
# 789                  NaN                     NaN                    NaN
# 790                  NaN                     NaN                    NaN
# 791                  NaN                     NaN                    NaN
#
#      sog_w2_unsafe_strdis_dis  sog_w2_wrk_yes  ...  sog_w2_nb_chldrn_2under6  \
# 0                        69.0            54.0  ...                       NaN
# 1                        73.0            59.0  ...                       NaN
# 2                        71.0            56.0  ...                       NaN
# 3                         6.0            56.0  ...                       8.0
# 4                        12.0            65.0  ...                      20.0
# ..                        ...             ...  ...                       ...
# 787                      39.0            61.0  ...                       NaN
# 788                      39.0            55.0  ...                       NaN
# 789                       NaN             NaN  ...                       NaN
# 790                       NaN             NaN  ...                       NaN
# 791                       NaN             NaN  ...                       NaN
#
#      sog_w2_nb_chldrn_3under6  sog_w2_nb_chldrn_over3  sog_w2_nb_chldrn_none  \
# 0                         NaN                     NaN                    NaN
# 1                         NaN                     NaN                    NaN
# 2                         NaN                     NaN                    NaN
# 3                         6.0                     4.0                   39.0
# 4                         7.0                     8.0                   31.0
# ..                        ...                     ...                    ...
# 787                       NaN                     NaN                    NaN
# 788                       NaN                     NaN                    NaN
# 789                       NaN                     NaN                    NaN
# 790                       NaN                     NaN                    NaN
# 791                       NaN                     NaN                    NaN
#
#      sog_w2_educ_none  sog_w2_educ_prim  sog_w2_educ_second  \
# 0                 NaN               NaN                 NaN
# 1                 NaN               NaN                 NaN
# 2                 NaN               NaN                 NaN
# 3                 4.0               7.0                14.0
# 4                 3.0               7.0                18.0
# ..                ...               ...                 ...
# 787               NaN               NaN                 NaN
# 788               NaN               NaN                 NaN
# 789               NaN               NaN                 NaN
# 790               NaN               NaN                 NaN
# 791               NaN               NaN                 NaN
#
#      sog_w2_educ_oversecond  sog_w2_educ_uniunderg  sog_w2_educ_unigrad
# 0                       NaN                    NaN                  NaN
# 1                       NaN                    NaN                  NaN
# 2                       NaN                    NaN                  NaN
# 3                      19.0                   49.0                  7.0
# 4                      18.0                   46.0                  9.0
# ..                      ...                    ...                  ...
# 787                     NaN                    NaN                  NaN
# 788                     NaN                    NaN                  NaN
# 789                     NaN                    NaN                  NaN
# 790                     NaN                    NaN                  NaN
# 791                     NaN                    NaN                  NaN
#
# [792 rows x 260 columns]

# %%
data.to_excel('Country_after_tran.xlsx')
